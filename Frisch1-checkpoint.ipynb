# %% [markdown]
# # Kevin Frisch
# ## "Phases of Analysis and Visualization"
# 1. Get the Data
# 2. Clean the data
# 3. Prepare the data
# 4. Analyze the data
# 5. Visualize the data

# %%
import pandas as pd
poll_url = 'https://projects.fivethirtyeight.com/general-model/president_general_polls_2016.csv'
polls = pd.read_csv(poll_url)
polls
# Out:
#        cycle     branch        type                        matchup  \
# 0       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 1       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 2       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 3       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 4       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# ...      ...        ...         ...                            ...
# 12619   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12620   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12621   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12622   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12623   2016  President  polls-only  Clinton vs. Trump vs. Johnson
#
#       forecastdate          state   startdate    enddate  \
# 0          11/8/16           U.S.   11/3/2016  11/6/2016
# ...

# %%
polls.head()
# Out:
#    cycle     branch        type                        matchup forecastdate  \
# 0   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 1   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 2   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 3   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 4   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
#
#   state  startdate    enddate                  pollster grade  ...  \
# 0  U.S.  11/3/2016  11/6/2016  ABC News/Washington Post    A+  ...
# 1  U.S.  11/1/2016  11/7/2016   Google Consumer Surveys     B  ...
# 2  U.S.  11/2/2016  11/6/2016                     Ipsos    A-  ...
# 3  U.S.  11/4/2016  11/7/2016                    YouGov     B  ...
# 4  U.S.  11/3/2016  11/6/2016          Gravis Marketing    B-  ...
#
#    adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# ...

# %%
import pandas as pd
poll_url = 'https://projects.fivethirtyeight.com/general-model/president_general_polls_2016.csv'
polls = pd.read_csv(poll_url)

polls.sort_values("state", axis = 0, ascending = True, inplace = True, na_position ='first')

polls
# Out:
#        cycle     branch        type                        matchup  \
# 12475   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 3304    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 9971    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 3318    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 1877    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# ...      ...        ...         ...                            ...
# 10098   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 1336    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 11204   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 5908    2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 5595    2016  President    now-cast  Clinton vs. Trump vs. Johnson
#
#       forecastdate    state   startdate     enddate                 pollster  \
# 12475      11/8/16  Alabama  10/21/2016   11/2/2016                    Ipsos
# ...

# %% [markdown]
# # Use Tab completion and tooltips

# %%
polls.sort_values('state',ascending=False)
# Out:
#        cycle     branch        type                        matchup  \
# 5595    2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 6453    2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 9752    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 2788    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 9761    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# ...      ...        ...         ...                            ...
# 5554    2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 2200    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 8930    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 4610    2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 12475   2016  President  polls-only  Clinton vs. Trump vs. Johnson
#
#       forecastdate    state   startdate     enddate                 pollster  \
# 5595       11/8/16  Wyoming  10/24/2016  10/30/2016             SurveyMonkey
# ...

# %%
# %%time
polls = polls.sort_values('state', ascending=False)
# Out:
# CPU times: total: 0 ns
# Wall time: 14.5 ms

# %%
# %whos
# Out:
# Variable   Type         Data/Info
# ---------------------------------
# pd         module       <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# poll_url   str          https://projects.fivethir<...>nt_general_polls_2016.csv
# polls      DataFrame           cycle     branch  <...>[12624 rows x 27 columns]

# %%
type(polls)
# Out:
# pandas.core.frame.DataFrame
