# %% [markdown]
# # Chapter 2 Assignment

# %% [markdown]
# ## Kevin Frisch

# %%
import pandas as pd

# %%
ramen_data = pd.read_csv("ramen-ratings.csv")

# %%
ramen_data.head()
# Out:
#             Brand                                            Variety Style  \
# 0       New Touch                          T's Restaurant Tantanmen    Cup
# 1        Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2          Nissin                      Cup Noodles Chicken Vegetable   Cup
# 3         Wei Lih                      GGE Ramen Snack Tomato Flavor  Pack
# 4  Ching's Secret                                    Singapore Curry  Pack
#
#   Country  Stars
# 0   Japan   3.75
# 1  Taiwan   1.00
# 2     USA   2.25
# 3  Taiwan   2.75
# 4   India   3.75

# %%
ramen_data.tail(5)
# Out:
#          Brand                                            Variety Style  \
# 2572     Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl
# 2573   Wai Wai                     Oriental Style Instant Noodles  Pack
# 2574   Wai Wai                                     Tom Yum Shrimp  Pack
# 2575   Wai Wai                               Tom Yum Chili Flavor  Pack
# 2576  Westbrae                                         Miso Ramen  Pack
#
#        Country  Stars
# 2572   Vietnam    3.5
# 2573  Thailand    1.0
# 2574  Thailand    2.0
# 2575  Thailand    2.0
# 2576       USA    0.5

# %%
ramen_data.describe()
# Out:
#              Stars
# count  2577.000000
# mean      3.654676
# std       1.015331
# min       0.000000
# 25%       3.250000
# 50%       3.750000
# 75%       4.250000
# max       5.000000

# %%
ramen_data.nunique()
# Out:
# Brand       355
# Variety    2410
# Style         7
# Country      38
# Stars        42
# dtype: int64

# %%
Vietnam = (ramen_data['Country']== 'Vietnam')
ramen_data.loc[Vietnam, ('Brand', 'Variety', 'Style', 'Country', 'Stars')]
# Out:
#               Brand                                            Variety Style  \
# 18         Binh Tay                                         Mi Hai Cua  Pack
# 52    Uni-President                                    Mushroom Flavor  Pack
# 143        Mum Ngon                                   Lau Tom Chua Cay  Pack
# 224           Vifon  Viet Cuisine Bun Rieu Cua Sour Crab Soup Insta...  Bowl
# 365         Acecook                             Oh! Ricey Pork Flavour  Pack
# ...             ...                                                ...   ...
# 2486       Binh Tay                                   Mi Chay Mushroom  Pack
# 2535        Ve Wong                             Kung-Fu Chicken Flavor  Pack
# 2570        Ve Wong                                      Mushroom Pork  Pack
# 2571          Vifon                                           Nam Vang  Pack
# 2572          Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl
#
#       Country  Stars
# 18    Vietnam   4.00
# ...

# %%
ramen_data[["Brand", "Style"]]
# Out:
#                Brand Style
# 0          New Touch   Cup
# 1           Just Way  Pack
# 2             Nissin   Cup
# 3            Wei Lih  Pack
# 4     Ching's Secret  Pack
# ...              ...   ...
# 2572           Vifon  Bowl
# 2573         Wai Wai  Pack
# 2574         Wai Wai  Pack
# 2575         Wai Wai  Pack
# 2576        Westbrae  Pack
#
# [2577 rows x 2 columns]

# %%
ramen_data["Country"]
# Out:
# 0          Japan
# 1         Taiwan
# 2            USA
# 3         Taiwan
# 4          India
#           ...
# 2572     Vietnam
# 2573    Thailand
# 2574    Thailand
# 2575    Thailand
# 2576         USA
# Name: Country, Length: 2577, dtype: object

# %%
ramen_data.sort_values('Stars', ascending=False)
# Out:
#                Brand                                            Variety Style  \
# 1585     Prima Taste                            Singapore Laksa La Mian  Pack
# 446         Maruchan  Instant Lunch Chipotle Chicken Flavor Ramen No...   Cup
# 484         Nongshim          Champong Noodle Soup Spicy Seafood Flavor  Pack
# 483           Nissin                              Straits Kitchen Laksa  Pack
# 1613          Nissin                 Raoh Backfat Rich Soy Sauce Flavor  Bowl
# ...              ...                                                ...   ...
# 522             Koyo                 Garlic Pepper Reduced Sodium Ramen  Pack
# 561    Samyang Foods                            Honey & Cheese Big Bowl  Bowl
# 950            Azami                                Kimchee Noodle Soup   Cup
# 2079  Hsin Tung Yang                     Tiny Noodle With Oyster Flavor  Pack
# 52     Uni-President                                    Mushroom Flavor  Pack
#
#           Country  Stars
# ...

# %%
ramen_data.Country.str.replace('USA', 'United States').head()
# Out:
# 0            Japan
# 1           Taiwan
# 2    United States
# 3           Taiwan
# 4            India
# Name: Country, dtype: object

# %%
ramen_data.Country.value_counts()
# Out:
# Japan            352
# USA              323
# South Korea      307
# Taiwan           224
# Thailand         191
# China            169
# Malaysia         155
# Hong Kong        137
# Indonesia        126
# Singapore        109
# Vietnam          108
# UK                69
# Philippines       47
# Canada            41
# India             31
# Germany           27
# Mexico            25
# Australia         22
# Netherlands       15
# Myanmar           14
# Nepal             14
# Pakistan           9
# Hungary            9
# Bangladesh         7
# Colombia           6
# Brazil             5
# Cambodia           5
# Fiji               4
# Holland            4
# Poland             4
# Finland            3
# Sarawak            3
# Sweden             3
# Dubai              3
# Ghana              2
# Estonia            2
# Nigeria            1
# United States      1
# Name: Country, dtype: int64

# %%
ramen_data.groupby('Country').agg({'Stars':['mean']}).head(3)
# Out:
#                Stars
#                 mean
# Country
# Australia   3.138636
# Bangladesh  3.714286
# Brazil      4.350000

# %%
ramen_data.groupby('Country').agg({"Stars":["min"]}).head(3)
# Out:
#            Stars
#              min
# Country
# Australia   1.00
# Bangladesh  3.25
# Brazil      4.00

# %%
# %%time
ramen_data.groupby('Country').agg({"Stars":["min"]}).head(3)
# Out:
# CPU times: total: 0 ns
# Wall time: 3.15 ms
#            Stars
#              min
# Country
# Australia   1.00
# Bangladesh  3.25
# Brazil      4.00
